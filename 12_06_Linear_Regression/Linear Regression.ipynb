# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['Id'].nunique()
# Out:
# 150

# %%
df1 = df.drop(['Id','Species'], axis=1)
df1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
sns.histplot(df['PetalLengthCm'])
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
df[df['PetalLengthCm'].between(2.2,2.9)]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df[df['PetalLengthCm'].between(1,1.6)].shape
# Out:
# (44, 6)

# %%
sns.histplot(df['PetalLengthCm'], kde =True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.kdeplot(df['PetalLengthCm'])
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.pairplot(df1)

# %%
sns.scatterplot(df['PetalLengthCm'], df['PetalWidthCm'])
# Out:
# C:\Users\cheta\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.scatterplot(df['PetalLengthCm'], df['PetalLengthCm'])
# Out:
# C:\Users\cheta\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalLengthCm'>

# %%
corr = df1.corr()
corr
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.savefig('Corr_Matrix1.jpg')

# %%
plt.figure(figsize=(5,3))
sns.heatmap(corr, annot=True, cmap='gist_heat')
plt.savefig('Corr_Matrix2.jpg')
